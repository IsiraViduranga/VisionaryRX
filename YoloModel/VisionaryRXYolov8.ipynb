# %%
# Install Ultralytics package
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# Mount Google Drive account to Google Colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Setting up paths
train_path_img = "./VisionaryRX/train/images/"
train_path_label = "./VisionaryRX/train/labels/*"
val_path_img = "./VisionaryRX/valid/images/"
val_path_label = "./VisionaryRX/valid/labels/"
test_path = "./VisionaryRX/test/images/"

# %%
# Checks if the dependencies required for Ultralytics are installed
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.53 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 25.5/78.2 GB disk)

# %%
# Training the model
# !yolo task=detect mode=train model=yolov8m.pt data=/content/drive/MyDrive/VisionaryRX/data.yaml epochs=100 imgsz=288 batch=8 project=/content/drive/MyDrive/Results name=VisionaryRXModel
# Out:
# ...
# 100% 49.7M/49.7M [00:01<00:00, 52.1MB/s]
# Ultralytics YOLOv8.0.53 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
#Predict on unseen images and saving predictions
# !yolo task=detect mode=predict model=/content/drive/MyDrive/Results/VisionaryRXModel/weights/best.pt conf=0.55 source=/content/drive/MyDrive/RandomTesting save=True
# Out:
# Ultralytics YOLOv8.0.53 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25843234 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/216 /content/drive/MyDrive/RandomTesting/00000000.jpg: 288x288 1 Decolgen, 16.6ms
# image 2/216 /content/drive/MyDrive/RandomTesting/00000001.jpg: 288x288 1 Alaxan, 1 Bioflu, 1 Biogesic, 16.9ms
# image 3/216 /content/drive/MyDrive/RandomTesting/00000002.jpg: 288x288 1 Bioflu, 1 KremilS, 17.9ms
# image 4/216 /content/drive/MyDrive/RandomTesting/00000003.jpg: 288x288 1 Alaxan, 1 KremilS, 29.3ms
# image 5/216 /content/drive/MyDrive/RandomTesting/00000004.jpg: 288x288 1 DayZinc, 16.4ms
# image 6/216 /content/drive/MyDrive/RandomTesting/00000005.jpg: 288x288 1 Bioflu, 1 DayZinc, 17.3ms
# image 7/216 /content/drive/MyDrive/RandomTesting/00000006.jpg: 288x288 1 Biogesic, 1 DayZinc, 16.4ms
# image 8/216 /content/drive/MyDrive/RandomTesting/00000007.jpg: 288x288 1 Decolgen, 1 KremilS, 16.9ms
# ...

# %%
# Saving prediction images to Google Drive
# !cp -r /content/runs/detect/predict /content/drive/MyDrive/OutputImages
